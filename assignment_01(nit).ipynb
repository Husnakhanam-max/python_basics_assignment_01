# %% [markdown]
# # *ASSIGNMENT_01*

# %% [markdown]
# HUSNA KHANAM \
# ROLL NO.61

# %% [markdown]
# - ### Beginner Problems: Simple If/Elif/Else

# %% [markdown]
# 1. Create a variable flavor and set it to "chocolate". Use an if statement to check if the flavor is "vanilla". If it is, print "I like vanilla!"

# %%
flavor = "chocolate"
flavor = input('Enter the flavor of ice cream:')
if flavor == "vanilla":
     print('I like vanilla!')
# Out:
# I like vanilla!

# %% [markdown]
# 2. Create a variable scoops and set it to 2. Write a conditional statement that prints "One scoop" if scoops is 1, and "More than one scoop" otherwise.

# %%
scoops = 2
if scoops == 1:
    print('One scoop') 
else:
    print('More than one scoop')
# Out:
# More than one scoop

# %% [markdown]
# 3. A customer wants to know the price. If their order is for "small" size, the price is 3.00. If it's not, the price is 5.00. Write a script to calculate and print the price.

# %%
size=input('Enter the size')
if size == 'small':
    print('The price is 3.00')
else:
    print('The price is 5.00')
# Out:
# The price is 3.00

# %% [markdown]
# 4. Write a script that checks if a variable is_vegan is True. If so, print "Show them the vegan options."

# %%
is_vegan = True
if is_vegan:
    print("Show them the vegan options.")
# Out:
# Show them the vegan options.

# %% [markdown]
# 5. A new flavor is added to the menu. Check if a variable new_flavor is "mint" or "strawberry". If it's either, print "That's a popular choice!"

# %%
new_flavor = 'mint','strawberry'
flavor = input('Enter the flavor')
if flavor in new_flavor:
    print("That's a popular choice!")

#just to see i have taken flavor == 'mint','strawberry' but it is not generating any output
# Out:
# That's a popular choice!

# %% [markdown]
# 6. Write a program that determines if an ice cream shop is open. If a variable current_hour is between 10 and 22 (inclusive), print "The shop is open!"

# %%
current_hour = input ('Enter the current_hour')
current_hour = int(current_hour)
if current_hour >= 10 and current_hour <= 22:
    print('The shop is open!')
# Out:
# The shop is open!

# %% [markdown]
# 7. A customer's age is 12. If their age is 12 or less, give them a free topping. Print "You get a free topping!"

# %%
customer_age= input('Enter your age: ')
customer_age = int(customer_age)
if customer_age <= 12:
    print("You get a free topping!")
# Out:
# You get a free topping!

# %% [markdown]
# 8. A customer wants a cone. If their choice is "cone", the cone costs an extra 0.50. Calculate the total cost of a 4.00 ice cream with a cone.

# %%
customer_wants ='cone'
ice_cream_price=4.00
if customer_wants == 'cone':
    print('The cone costs an extra 0.50')
    final_price = ice_cream_price + 0.50 
print('The final price is :',final_price)
# Out:
# The cone costs an extra 0.50
# The final price is : 4.5

# %% [markdown]
# 9. A discount is available. If a variable day_of_week is "Monday", print "You get a 10% discount!"

# %%
day = input('Enter what day is it?:')
if day == 'monday':
   print("You get a 10% discount!")
# Out:
# You get a 10% discount!

# %% [markdown]
# 10. A customer has a loyalty card. If the variable has_loyalty_card is True, print "Thank you for being a loyal customer!"

# %%
has_loyalty_card = True
if has_loyalty_card:
    print('Thank you for being a loyal customer!')
# Out:
# Thank you for being a loyal customer!

# %% [markdown]
# 11. Write a script to check if the variable topping is not equal to "sprinkles". If it's not, print "We'll add a different topping."

# %%
n = input('Is the topping equal to sprinkles?')
if n == 'no':
    print("We'll add a different topping")
# Out:
# We'll add a different topping

# %% [markdown]
# 12. The shop is out of a certain flavor. If a variable flavor_is_available is False, print "Sorry, that flavor is unavailable."

# %%
flavor = False
if flavor:
    print("Do you want to add flavor to your coffee?")
print("Sorry , that flavour is not available")
# Out:
# Sorry , that flavour is not available

# %% [markdown]
# 13. Check if a customer's order has a total price of exactly 5.50. If it does, print "Exact amount needed."

# %%
price = input('Please Enter the price of the item: ')
price = float(price)
if price == 5.50:
    print('Exact amount needed')
# Out:
# Exact amount needed

# %% [markdown]
# - ## Intermediate Problems: Nested and Combined Logic

# %% [markdown]
# 1. A customer wants a "large" size ice cream. If the size is "large", and the flavor is "chocolate", print "Large chocolate cone coming up!". Otherwise, print "Sorry, we only have large in chocolate."

# %%
ice_cream_size = "Large"
flavor = "Chocolate"

if ice_cream_size == "Large" and flavor == "Chocolate":
    print("Large chocolate cone coming up!")
elif ice_cream_size == "Small" and flavor == "Vanilla":
    print("Small vanilla cone coming up!")
else:
    print("Sorry, we only have large in chocolate.")
# Out:
# Large chocolate cone coming up!

# %% [markdown]
# 2. A customer can get a discount if their order total is over 10.00 OR if they are a senior (age 65 or older). Write a script that checks for these conditions and prints "Discount applied." if either is true.

# %%
order_total = 10
age = 65

if order_total >= 10 or age >= 65:
    print('Discount Applied')
elif order_total >= 5 and age < 65:
    print('Discount Applied')
else:
    print('No Discount')
# Out:
# Discount Applied

# %% [markdown]
# 3. A special offer is available for a two-scoop vanilla cone. Write a nested if statement that checks if the number of scoops is 2. Inside that, check if the flavor is "vanilla". If both are true, print "Special offer for you!"

# %%
scoop = 2
flavor = 'vanilla'

if scoop == 2 and flavor == 'vanilla':
    print('Special offer for you!')
elif scoop == 1:
    print('You have one scoop of vanilla')
else :
    print('You have more than one scoop of vanilla')
# Out:
# Special offer for you!

# %% [markdown]
# 4. A customer has a coupon for a free topping. Write a script that checks if their order has at least 2 scoops AND they have a coupon. If so, print "Free topping added."

# %%
scoops = 2 
coupon = True

if scoops >= 2 and coupon:
    print('Free toppings added')
else:
    print('No free toppings')
# Out:
# Free toppings added

# %% [markdown]
# 5. Write a script that checks a customer's order for size, scoops, and flavor. If the size is "medium", and the scoops are 3, and the flavor is not "strawberry", print "This is a custom order!"

# %%
order_size = 'medium'
scoops = 3 
flavour = "vanilla"

if order_size == 'medium' and scoops == 3 and flavour == "vanilla":
    print('This is a custom order')
else:
    print('This is not a custom order')
# Out:
# This is a custom order

# %% [markdown]
# 6. The weather affects sales. If the temperature is above 25 degrees AND the time of day is after 15:00 (3 PM), print "It's a hot afternoon, time for a rush!"

# %%
temp = 26
time = 4

if temp>20 and time>3:
   print("It's a hot afternoon, time for a rush!")
   
# sir how do we write 14:00 in this code?
# Out:
# It's a hot afternoon, time for a rush!

# %% [markdown]
# 7. A new VIP program is being tested. If a customer is a VIP, they get a free topping. If they are a VIP AND a senior, they get a free topping and a free scoop. Write a script to handle both cases.

# %%
customer =  "VIP"
age_group =  "Adult"

if customer == "VIP":
    print("congratulations! You got a free topping")
elif customer == "VIP" and age_group == "senior":
    print("congratulations! You got a free topping and a free scoop")
else:
    print("Sorry, you don't qualify for a free topping")
# Out:
# congratulations! You got a free topping
